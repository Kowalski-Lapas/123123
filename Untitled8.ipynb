# %%
import os
import json
import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.feature_extraction.text import CountVectorizer
import sklearn
from sklearn.naive_bayes import MultinomialNB
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.datasets import fetch_20newsgroups
PATH_TO_DATA = r'C:\Users\davyd\Downloads\txt'


file_contents_list = [] # сюда записываем всё содержимое файлов
for filename in os.listdir(PATH_TO_DATA):
    print(filename)
    with open(f'{PATH_TO_DATA}/{filename}', 'r', encoding='utf-8') as f:
        dict_file_content = json.loads(f.read()) # считываем содержимое файла
        # обращаемся к конкретному полю rewiews, по которому можем получить весь массив
        for rewiew in dict_file_content['reviews']:
            # каждую запись в этом массиве добавляем в список в виде датафрейма
            file_contents_list.append(pd.DataFrame(rewiew, index=[0]))

# склеиваем датафреймы в один
data = pd.concat(file_contents_list, ignore_index=True)

data.head(5)
# Out:
# 55544 — копия (10) — копия — копия — копия — копия.txt
# 55544 — копия (10) — копия — копия — копия.txt
# 55544 — копия (10) — копия — копия.txt
# 55544 — копия (10) — копия.txt
# 55544 — копия (11) — копия — копия — копия — копия.txt
# 55544 — копия (11) — копия — копия — копия.txt
# 55544 — копия (11) — копия — копия.txt
# 55544 — копия (11) — копия.txt
# 55544 — копия (12) — копия — копия — копия — копия.txt
# 55544 — копия (12) — копия — копия — копия.txt
# 55544 — копия (12) — копия — копия.txt
# 55544 — копия (12) — копия.txt
# 55544 — копия (13) — копия — копия — копия — копия.txt
# 55544 — копия (13) — копия — копия — копия.txt
# 55544 — копия (13) — копия — копия.txt
# 55544 — копия (13) — копия.txt
# 55544 — копия (14) — копия — копия — копия — копия.txt
# 55544 — копия (14) — копия — копия — копия.txt
# 55544 — копия (14) — копия — копия.txt
# 55544 — копия (14) — копия.txt
# 55544 — копия (15) — копия — копия — копия — копия.txt
# 55544 — копия (15) — копия — копия — копия.txt
# 55544 — копия (15) — копия — копия.txt
# 55544 — копия (15) — копия.txt
# 55544 — копия (16) — копия — копия — копия — копия.txt
# 55544 — копия (16) — копия — копия — копия.txt
# 55544 — копия (16) — копия — копия.txt
# 55544 — копия (16) — копия.txt
# 55544 — копия (17) — копия — копия — копия — копия.txt
# 55544 — копия (17) — копия — копия — копия.txt
# 55544 — копия (17) — копия — копия.txt
# 55544 — копия (17) — копия.txt
# 55544 — копия (18) — копия — копия — копия — копия.txt
# 55544 — копия (18) — копия — копия — копия.txt
# 55544 — копия (18) — копия — копия.txt
# 55544 — копия (18) — копия.txt
# 55544 — копия (19) — копия — копия — копия — копия.txt
# 55544 — копия (19) — копия — копия — копия.txt
# 55544 — копия (19) — копия — копия.txt
# 55544 — копия (19) — копия.txt
# 55544 — копия (2) — копия — копия — копия — копия — копия — копия.txt
# 55544 — копия (2) — копия — копия — копия — копия — копия.txt
# 55544 — копия (2) — копия — копия — копия — копия.txt
# 55544 — копия (2) — копия — копия — копия.txt
# 55544 — копия (2) — копия — копия.txt
# 55544 — копия (2) — копия.txt
# 55544 — копия (2).txt
# 55544 — копия (20) — копия — копия — копия — копия.txt
# 55544 — копия (20) — копия — копия — копия.txt
# 55544 — копия (20) — копия — копия.txt
# 55544 — копия (20) — копия.txt
# 55544 — копия (21) — копия — копия — копия — копия.txt
# 55544 — копия (21) — копия — копия — копия.txt
# 55544 — копия (21) — копия — копия.txt
# 55544 — копия (21) — копия.txt
# 55544 — копия (22) — копия — копия — копия — копия.txt
# 55544 — копия (22) — копия — копия — копия.txt
# 55544 — копия (22) — копия — копия.txt
# 55544 — копия (22) — копия.txt
# 55544 — копия (23) — копия — копия — копия.txt
# 55544 — копия (23) — копия — копия.txt
# 55544 — копия (24) — копия — копия — копия.txt
# 55544 — копия (24) — копия — копия.txt
# 55544 — копия (25) — копия — копия — копия.txt
# 55544 — копия (25) — копия — копия.txt
# 55544 — копия (26) — копия — копия — копия.txt
# 55544 — копия (26) — копия — копия.txt
# 55544 — копия (27) — копия — копия — копия.txt
# 55544 — копия (27) — копия — копия.txt
# 55544 — копия (28) — копия — копия — копия.txt
# 55544 — копия (28) — копия — копия.txt
# 55544 — копия (29) — копия — копия — копия.txt
# 55544 — копия (29) — копия — копия.txt
# 55544 — копия (3) — копия — копия — копия — копия — копия.txt
# 55544 — копия (3) — копия — копия — копия — копия.txt
# 55544 — копия (3) — копия — копия — копия.txt
# 55544 — копия (3) — копия — копия.txt
# 55544 — копия (3) — копия.txt
# 55544 — копия (3).txt
# 55544 — копия (30) — копия — копия — копия.txt
# 55544 — копия (30) — копия — копия.txt
# 55544 — копия (31) — копия — копия — копия.txt
# 55544 — копия (31) — копия — копия.txt
# 55544 — копия (32) — копия — копия — копия.txt
# 55544 — копия (32) — копия — копия.txt
# 55544 — копия (33) — копия — копия — копия.txt
# 55544 — копия (33) — копия — копия.txt
# 55544 — копия (34) — копия — копия — копия.txt
# 55544 — копия (34) — копия — копия.txt
# 55544 — копия (35) — копия — копия — копия.txt
# 55544 — копия (35) — копия — копия.txt
# 55544 — копия (36) — копия — копия — копия.txt
# 55544 — копия (36) — копия — копия.txt
# 55544 — копия (4) — копия — копия — копия — копия — копия.txt
# 55544 — копия (4) — копия — копия — копия — копия.txt
# 55544 — копия (4) — копия — копия — копия.txt
# 55544 — копия (4) — копия — копия.txt
# 55544 — копия (4) — копия.txt
# 55544 — копия (4).txt
# 55544 — копия (5) — копия — копия — копия — копия — копия.txt
# 55544 — копия (5) — копия — копия — копия — копия.txt
# 55544 — копия (5) — копия — копия — копия.txt
# 55544 — копия (5) — копия — копия.txt
# 55544 — копия (5) — копия.txt
# 55544 — копия (5).txt
# 55544 — копия (6) — копия — копия — копия — копия — копия.txt
# 55544 — копия (6) — копия — копия — копия — копия.txt
# 55544 — копия (6) — копия — копия — копия.txt
# 55544 — копия (6) — копия — копия.txt
# 55544 — копия (6) — копия.txt
# 55544 — копия (6).txt
# 55544 — копия (7) — копия — копия — копия — копия — копия.txt
# 55544 — копия (7) — копия — копия — копия — копия.txt
# 55544 — копия (7) — копия — копия — копия.txt
# 55544 — копия (7) — копия — копия.txt
# 55544 — копия (7) — копия.txt
# 55544 — копия (7).txt
# 55544 — копия (8) — копия — копия — копия — копия — копия.txt
# 55544 — копия (8) — копия — копия — копия — копия.txt
# 55544 — копия (8) — копия — копия — копия.txt
# 55544 — копия (8) — копия — копия.txt
# 55544 — копия (8) — копия.txt
# 55544 — копия (8).txt
# 55544 — копия (9) — копия — копия — копия — копия.txt
# 55544 — копия (9) — копия — копия — копия.txt
# 55544 — копия (9) — копия — копия.txt
# 55544 — копия (9) — копия.txt
# 55544 — копия — копия (10) — копия — копия — копия.txt
# 55544 — копия — копия (10) — копия — копия.txt
# 55544 — копия — копия (10) — копия.txt
# 55544 — копия — копия (11) — копия — копия — копия.txt
# 55544 — копия — копия (11) — копия — копия.txt
# 55544 — копия — копия (11) — копия.txt
# 55544 — копия — копия (12) — копия — копия — копия.txt
# 55544 — копия — копия (12) — копия — копия.txt
# 55544 — копия — копия (12) — копия.txt
# 55544 — копия — копия (13) — копия — копия — копия.txt
# 55544 — копия — копия (13) — копия — копия.txt
# 55544 — копия — копия (13) — копия.txt
# 55544 — копия — копия (14) — копия — копия — копия.txt
# 55544 — копия — копия (14) — копия — копия.txt
# 55544 — копия — копия (14) — копия.txt
# 55544 — копия — копия (15) — копия — копия — копия.txt
# 55544 — копия — копия (15) — копия — копия.txt
# 55544 — копия — копия (15) — копия.txt
# 55544 — копия — копия (16) — копия — копия — копия.txt
# 55544 — копия — копия (16) — копия — копия.txt
# 55544 — копия — копия (16) — копия.txt
# 55544 — копия — копия (17) — копия — копия.txt
# 55544 — копия — копия (18) — копия — копия.txt
# 55544 — копия — копия (19) — копия — копия.txt
# 55544 — копия — копия (2) — копия — копия — копия — копия — копия.txt
# 55544 — копия — копия (2) — копия — копия — копия — копия.txt
# 55544 — копия — копия (2) — копия — копия — копия.txt
# 55544 — копия — копия (2) — копия — копия.txt
# 55544 — копия — копия (2) — копия.txt
# 55544 — копия — копия (2).txt
# 55544 — копия — копия (20) — копия — копия.txt
# 55544 — копия — копия (21) — копия — копия.txt
# 55544 — копия — копия (3) — копия — копия — копия — копия.txt
# 55544 — копия — копия (3) — копия — копия — копия.txt
# 55544 — копия — копия (3) — копия — копия.txt
# 55544 — копия — копия (3) — копия.txt
# 55544 — копия — копия (3).txt
# 55544 — копия — копия (4) — копия — копия — копия — копия.txt
# 55544 — копия — копия (4) — копия — копия — копия.txt
# 55544 — копия — копия (4) — копия — копия.txt
# 55544 — копия — копия (4) — копия.txt
# 55544 — копия — копия (4).txt
# 55544 — копия — копия (5) — копия — копия — копия — копия.txt
# 55544 — копия — копия (5) — копия — копия — копия.txt
# 55544 — копия — копия (5) — копия — копия.txt
# 55544 — копия — копия (5) — копия.txt
# 55544 — копия — копия (5).txt
# 55544 — копия — копия (6) — копия — копия — копия — копия.txt
# 55544 — копия — копия (6) — копия — копия — копия.txt
# 55544 — копия — копия (6) — копия — копия.txt
# 55544 — копия — копия (6) — копия.txt
# 55544 — копия — копия (6).txt
# 55544 — копия — копия (7) — копия — копия — копия — копия.txt
# 55544 — копия — копия (7) — копия — копия — копия.txt
# 55544 — копия — копия (7) — копия — копия.txt
# 55544 — копия — копия (7) — копия.txt
# 55544 — копия — копия (7).txt
# 55544 — копия — копия (8) — копия — копия — копия.txt
# 55544 — копия — копия (8) — копия — копия.txt
# 55544 — копия — копия (8) — копия.txt
# 55544 — копия — копия (9) — копия — копия — копия.txt
# 55544 — копия — копия (9) — копия — копия.txt
# 55544 — копия — копия (9) — копия.txt
# 55544 — копия — копия — копия (10) — копия — копия.txt
# 55544 — копия — копия — копия (10) — копия.txt
# 55544 — копия — копия — копия (11) — копия — копия.txt
# 55544 — копия — копия — копия (11) — копия.txt
# 55544 — копия — копия — копия (2) — копия — копия — копия — копия.txt
# 55544 — копия — копия — копия (2) — копия — копия — копия.txt
# 55544 — копия — копия — копия (2) — копия — копия.txt
# 55544 — копия — копия — копия (2) — копия.txt
# 55544 — копия — копия — копия (2).txt
# 55544 — копия — копия — копия (3) — копия — копия — копия.txt
# 55544 — копия — копия — копия (3) — копия — копия.txt
# 55544 — копия — копия — копия (3) — копия.txt
# 55544 — копия — копия — копия (3).txt
# 55544 — копия — копия — копия (4) — копия — копия — копия.txt
# 55544 — копия — копия — копия (4) — копия — копия.txt
# 55544 — копия — копия — копия (4) — копия.txt
# 55544 — копия — копия — копия (4).txt
# 55544 — копия — копия — копия (5) — копия — копия — копия.txt
# 55544 — копия — копия — копия (5) — копия — копия.txt
# 55544 — копия — копия — копия (5) — копия.txt
# 55544 — копия — копия — копия (5).txt
# 55544 — копия — копия — копия (6) — копия — копия — копия.txt
# 55544 — копия — копия — копия (6) — копия — копия.txt
# 55544 — копия — копия — копия (6) — копия.txt
# 55544 — копия — копия — копия (6).txt
# 55544 — копия — копия — копия (7) — копия — копия.txt
# 55544 — копия — копия — копия (7) — копия.txt
# 55544 — копия — копия — копия (8) — копия — копия.txt
# 55544 — копия — копия — копия (8) — копия.txt
# 55544 — копия — копия — копия (9) — копия — копия.txt
# 55544 — копия — копия — копия (9) — копия.txt
# 55544 — копия — копия — копия — копия (2) — копия — копия — копия.txt
# 55544 — копия — копия — копия — копия (2) — копия — копия.txt
# 55544 — копия — копия — копия — копия (2) — копия.txt
# 55544 — копия — копия — копия — копия (2).txt
# 55544 — копия — копия — копия — копия (3) — копия — копия.txt
# 55544 — копия — копия — копия — копия (3) — копия.txt
# 55544 — копия — копия — копия — копия (3).txt
# 55544 — копия — копия — копия — копия (4) — копия — копия.txt
# 55544 — копия — копия — копия — копия (4) — копия.txt
# 55544 — копия — копия — копия — копия (4).txt
# 55544 — копия — копия — копия — копия (5) — копия — копия.txt
# 55544 — копия — копия — копия — копия (5) — копия.txt
# 55544 — копия — копия — копия — копия (5).txt
# 55544 — копия — копия — копия — копия (6) — копия.txt
# 55544 — копия — копия — копия — копия (7) — копия.txt
# 55544 — копия — копия — копия — копия — копия (2) — копия — копия.txt
# 55544 — копия — копия — копия — копия — копия (2) — копия.txt
# 55544 — копия — копия — копия — копия — копия (2).txt
# 55544 — копия — копия — копия — копия — копия (3) — копия.txt
# 55544 — копия — копия — копия — копия — копия (3).txt
# 55544 — копия — копия — копия — копия — копия (4) — копия.txt
# 55544 — копия — копия — копия — копия — копия (4).txt
# 55544 — копия — копия — копия — копия — копия — копия (2) — копия.txt
# 55544 — копия — копия — копия — копия — копия — копия (2).txt
# 55544 — копия — копия — копия — копия — копия — копия (3).txt
# 55544 — копия — копия — копия — копия — копия — копия — копия (2).txt
# 55544 — копия — копия — копия — копия — копия — копия — копия — копия.txt
# 55544 — копия — копия — копия — копия — копия — копия — копия.txt
# 55544 — копия — копия — копия — копия — копия — копия.txt
# 55544 — копия — копия — копия — копия — копия.txt
# 55544 — копия — копия — копия — копия.txt
# 55544 — копия — копия — копия.txt
# 55544 — копия — копия.txt
# 55544 — копия.txt
# 55544.txt
#    id_client                                        review_text          label
# 0     243345  Мне очень не понравилась ваша ебучая фирма, у ...     Возмущение
# 1     363564   Круто, здоров, отлично! Товар высокого качества.        Радость
# 2     123456                                Ля, хрень какая-то.  Разочарование
# 3     243345  Мне очень не понравилась ваша ебучая фирма, у ...     Возмущение
# 4     363564   Круто, здоров, отлично! Товар высокого качества.        Радость

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_client    768 non-null    int64
#  1   review_text  768 non-null    object
#  2   label        768 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 18.1+ KB

# %%
count_vect = CountVectorizer()
from sklearn.feature_extraction.text import CountVectorizer
сount_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(data['review_text'])
X_train_counts.shape
# Out:
# (768, 22)

# %%
data
# Out:
#      id_client                                        review_text  \
# 0       243345  Мне очень не понравилась ваша ебучая фирма, у ...
# 1       363564   Круто, здоров, отлично! Товар высокого качества.
# 2       123456                                Ля, хрень какая-то.
# 3       243345  Мне очень не понравилась ваша ебучая фирма, у ...
# 4       363564   Круто, здоров, отлично! Товар высокого качества.
# ..         ...                                                ...
# 763     363564   Круто, здоров, отлично! Товар высокого качества.
# 764     123456                                Ля, хрень какая-то.
# 765     243345  Мне очень не понравилась ваша ебучая фирма, у ...
# 766     363564   Круто, здоров, отлично! Товар высокого качества.
# 767     123456                                Ля, хрень какая-то.
#
#              label
# 0       Возмущение
# 1          Радость
# 2    Разочарование
# 3       Возмущение
# 4          Радость
# ..             ...
# 763        Радость
# 764  Разочарование
# 765     Возмущение
# 766        Радость
# 767  Разочарование
#
# [768 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (768, 22)

# %%
data
# Out:
#      id_client                                        review_text  \
# 0       243345  Мне очень не понравилась ваша ебучая фирма, у ...
# 1       363564   Круто, здоров, отлично! Товар высокого качества.
# 2       123456                                Ля, хрень какая-то.
# 3       243345  Мне очень не понравилась ваша ебучая фирма, у ...
# 4       363564   Круто, здоров, отлично! Товар высокого качества.
# ..         ...                                                ...
# 763     363564   Круто, здоров, отлично! Товар высокого качества.
# 764     123456                                Ля, хрень какая-то.
# 765     243345  Мне очень не понравилась ваша ебучая фирма, у ...
# 766     363564   Круто, здоров, отлично! Товар высокого качества.
# 767     123456                                Ля, хрень какая-то.
#
#              label
# 0       Возмущение
# 1          Радость
# 2    Разочарование
# 3       Возмущение
# 4          Радость
# ..             ...
# 763        Радость
# 764  Разочарование
# 765     Возмущение
# 766        Радость
# 767  Разочарование
#
# [768 rows x 3 columns]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def text_processing(text):
    # удаление пунктуации
    remove_punc = [c for c in text if c not in string.punctuation]

# %%
text_processing.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 text_processing.shape
#
# AttributeError: 'function' object has no attribute 'shape'
